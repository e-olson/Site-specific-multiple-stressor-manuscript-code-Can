# %%
import pandas as pd
import numpy as np
import csv
import re
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv('dsinfo.txt',sep=None,index_col=0)
# Out:
# /tmp/ipykernel_2959470/1508095284.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   df0=pd.read_csv('dsinfo.txt',sep=None,index_col=0)

# %%
df0
# Out:
#                               datasetID  \
# index
# 0      pmel_co2_moorings_ba50_a09b_5565
# 1      pmel_co2_moorings_c2e7_ecb9_4565
# 2      pmel_co2_moorings_c64b_e2bb_dc32
# 3      pmel_co2_moorings_4e4c_1834_1204
# 4      pmel_co2_moorings_e1ef_470f_1fee
# 5      pmel_co2_moorings_939b_fc25_57be
# 6      pmel_co2_moorings_ab27_2faf_3aa1
# 7      pmel_co2_moorings_cf08_f32f_712a
# 8      pmel_co2_moorings_0af7_8b89_77bd
# 9      pmel_co2_moorings_045c_c8bc_b1c6
# 10     pmel_co2_moorings_3b97_8e9a_3b51
# 11     pmel_co2_moorings_ab03_dbac_935b
# 12     pmel_co2_moorings_ee12_e5fb_4537
# 13     pmel_co2_moorings_cb2d_135a_c444
# 14     pmel_co2_moorings_9675_b3d3_c1c1
# 15     pmel_co2_moorings_e27b_9478_5078
# 16     pmel_co2_moorings_47ca_cd17_f8f9
# 17     pmel_co2_moorings_299e_e649_3487
# 18     pmel_co2_moorings_fad6_8193_8d89
# 19     pmel_co2_moorings_fa67_c709_71e7
# 20     pmel_co2_moorings_d18e_ee9f_4615
# 21     pmel_co2_moorings_c53b_4693_578a
# ...

# %%
plt.plot(df0.Lon,df0.Lat,'r.')

# %%
df0.to_csv('dfInfoBuoy.csv')

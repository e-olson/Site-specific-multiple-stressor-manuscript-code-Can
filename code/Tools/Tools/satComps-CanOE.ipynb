# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import pandas as pd
import OAPBuoyData as OAP, commonfxns as cf, diagsPP, viz, OAPBuoyComp as bc
import cftime
import warnings
import datetime as dt
# Out:
# /home/ords/crd/ccrn/reo000/miniconda3/envs/py39dc2/lib/python3.9/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
iscen='CanESM5CanOE_1975_2022_monthly'
yrspan = diagsPP.dictScenDates[iscen]
freq='monthly' 
dfInfoBuoy=OAP.loadOAPInfo(modelgrid=True)
saveloc=bc.savebase + f"{diagsPP.scenNameDict[iscen]}/"
cf.mkdirs(saveloc)

# %%
saveloc
# Out:
# '/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/'

# %%
ind=0
dsid=dfInfoBuoy.datasetID[ind]

# %%
bc.run1CompScenSat(dsid,iscen,freq,saveloc,dfInfoBuoy)
# Out:
# pmel_co2_moorings_ba50_a09b_5565 Iceland  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 192
# 192
# 192
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']

# %%
for ind in range(1,41):
    print(ind)
    dsid=dfInfoBuoy.datasetID[ind]
    bc.run1CompScenSat(dsid,iscen,freq,saveloc,dfInfoBuoy)
# Out:
# 1
# pmel_co2_moorings_c2e7_ecb9_4565 Gulf of Maine  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 315
# 315
# 315
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']
# 2
# pmel_co2_moorings_c64b_e2bb_dc32 First Landing  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 315
# 315
# 315
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']
# 3
# pmel_co2_moorings_4e4c_1834_1204 Hog Reef  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 315
# 315
# 315
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']
# ...

# %%
for ind in range(20,41):
    print(ind)
    dsid=dfInfoBuoy.datasetID[ind]
    bc.run1CompScenSat(dsid,iscen,freq,saveloc,dfInfoBuoy)
# Out:
# 20
# pmel_co2_moorings_d18e_ee9f_4615 GAKOA  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 209
# 209
# 209
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']
# 21
# pmel_co2_moorings_c53b_4693_578a Kodiak  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 256
# 256
# 256
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']
# 22
# pmel_co2_moorings_87d0_7c04_27e0 M2  NOAA Surface Ocean CO2 and Ocean Acidification Mooring Time Series /space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/CanESM5CanOE_1975_2022_monthly/
# chlos
# 238
# 238
# 238
# Pickling, removing cf time classes: ['obs_tind', 'obs_tind_b', 'mod_tind', 'mod_intt', 'obs_intt']
# 23
# ...
